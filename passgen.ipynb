# %%
import random
password="QWERTYUIOPLKJHGFDSAZXCVBNMqwertyuioplkjhgfdsazxcvbnm1234567890!@#$%^&*()?"
length=int(input("Enter the password lenght"))
a="".join(random.sample(password,length))
print(f"your password is {a}")
# Out:
# Enter the password lenght8
# your password is R4nPTOxN
